# %% [markdown]
# - methodology
# https://english.sse.com.cn/indices/indices/list/indexmethods/c/000688_000688hbooken_EN.pdf
# - STAR market
# https://english.sse.com.cn/markets/equities/overview/

# %%
from help import *

# %%
univ = pd.read_csv('../data/star_board.csv')
tickers = univ['stock_code'].tolist()

# %%
symbol="688235"
df = ak.stock_individual_info_em(symbol=symbol)
print(df)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/venvs/jenv/lib/python3.12/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/venvs/jenv/lib/python3.12/site-packages/simplejson/__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
#     511         parse_int is None and parse_float is None and
#     512         parse_constant is None and object_pairs_hook is None
#     513         and not use_decimal and not allow_nan and not kw):
# --> 514     return _default_decoder.decode(s)
#     515 if cls is None:
#
# File ~/venvs/jenv/lib/python3.12/site-packages/simplejson/decoder.py:386, in JSONDecoder.decode(self, s, _w, _PY3)
#     385     s = str(s, self.encoding)
# --> 386 obj, end = self.raw_decode(s)
#     387 end = _w(s, end).end()
#
# File ~/venvs/jenv/lib/python3.12/site-packages/simplejson/decoder.py:416, in JSONDecoder.raw_decode(self, s, idx, _w, _PY3)
#     415         idx += 3
# --> 416 return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 symbol="688235"
# ----> 2 df = ak.stock_individual_info_em(symbol=symbol)
#       3 print(df)
#
# File ~/venvs/jenv/lib/python3.12/site-packages/akshare/stock/stock_info_em.py:41, in stock_individual_info_em(symbol, timeout)
#      28 params = {
#      29     "fltt": "2",
#      30     "invt": "2",
#    (...)     38     "secid": f"{market_code}.{symbol}",
#      39 }
#      40 r = requests.get(url, params=params, timeout=timeout)
# ---> 41 data_json = r.json()
#      42 temp_df = pd.DataFrame(data_json)
#      43 temp_df.reset_index(inplace=True)
#
# File ~/venvs/jenv/lib/python3.12/site-packages/requests/models.py:982, in Response.json(self, **kwargs)
#     978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 982     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def get_sse_stock_list(api_key):
	# API Endpoint for basic symbol information
	url = "https://data.infoway.io/common/basic/symbols"
	
	# Query parameters
	# type: STOCK_CN refers to China A-shares
	params = {
		"type": "STOCK_CN"
	}
	
	# Headers including your API key
	headers = {
		"apiKey": api_key,
		"Accept": "application/json"
	}

	try:
		response = requests.get(url, headers=headers, params=params)
		
		# Check if the request was successful
		if response.status_code == 200:
			all_stocks = response.json()
			
			# Filter for SSE (Shanghai Stock Exchange) shares
			# Infoway uses the suffix .SH for Shanghai and .SZ for Shenzhen
			sse_stocks = [
				stock for stock in all_stocks 
				if stock.get('symbol', '').endswith('.SH')
			]
			
			return sse_stocks
		else:
			print(f"Error: {response.status_code} - {response.text}")
			return None
			
	except Exception as e:
		print(f"An error occurred: {e}")
		return None

# --- Usage ---
YOUR_API_KEY = "4875280ab54e4da9abe2440416eaacae-infoway"
stocks = get_sse_stock_list(YOUR_API_KEY)

if stocks:
	print(f"Successfully retrieved {len(stocks)} stocks from SSE.")
	# Print the first 5 examples
	for stock in stocks[:5]:
		print(f"Symbol: {stock['symbol']}, Name: {stock.get('name', 'N/A')}")

# %%
url = "https://data.infoway.io/common/basic/symbols"

params = {
	"type": "STOCK_CN"
}

# Headers including your API key
headers = {
	"apiKey": YOUR_API_KEY,
	"Accept": "application/json"
}


resp = requests.get(url, headers=headers, params=params)

# %%
all_tickers = pd.DataFrame(resp.json()['data'])['symbol'].tolist()

# %%
sb_tiks = pd.read_csv('star_board.csv')['stock_code'].tolist()
sb_tiks = [str(tik) + ".SH" for tik in sb_tiks]

# %%
[x for x in sb_tiks if x not in all_tickers]
